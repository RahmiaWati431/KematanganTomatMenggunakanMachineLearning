# %% [markdown]
# <a href="https://colab.research.google.com/github/RahmiaWati431/KematanganTomatMenggunakanMachineLearning/blob/main/UjiNVB80_20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
from IPython.display import display
import pandas as pd
from statsmodels.stats.contingency_tables import mcnemar

# --- Mount Google Drive ---
drive.mount('/content/drive')

# --- Load Data NB ---
crop_df = pd.read_csv('/content/drive/MyDrive/Penelitian/Berkas/Crop/80:20/nvb/mvnemar/Prediksi_NBCrop_80:20.csv')
nocrop_df = pd.read_csv('/content/drive/MyDrive/Penelitian/Berkas/TanpaCrop/80:20/nvb/mcnemar/Prediksi_NB_Tanpa_Crop_80:20.csv')

# --- Pastikan urutannya sama ---
crop_df.sort_values(by='Filename', inplace=True)
nocrop_df.sort_values(by='Filename', inplace=True)
crop_df.reset_index(drop=True, inplace=True)
nocrop_df.reset_index(drop=True, inplace=True)

# --- Pastikan label asli sama ---
assert all(crop_df['Actual'] == nocrop_df['Actual']), "Ground truth tidak cocok!"

# --- Buat tabel evaluasi ---
evaluasi_df = pd.DataFrame({
    'Label Asli': crop_df['Actual'],
    'NB Crop Prediksi': crop_df['Predicted_NB_Crop'],
    'NB TanpaCrop Prediksi': nocrop_df['Predicted_NB_Crop'],
})

# Tambahkan kolom kebenaran prediksi
evaluasi_df['Crop Benar?'] = evaluasi_df['Label Asli'] == evaluasi_df['NB Crop Prediksi']
evaluasi_df['TanpaCrop Benar?'] = evaluasi_df['Label Asli'] == evaluasi_df['NB TanpaCrop Prediksi']

# Fungsi untuk menentukan kategori McNemar
def tentukan_kategori(row):
    if row['Crop Benar?'] and not row['TanpaCrop Benar?']:
        return 'b (Crop benar, TanpaCrop salah)'
    elif not row['Crop Benar?'] and row['TanpaCrop Benar?']:
        return 'c (Crop salah, TanpaCrop benar)'
    else:
        return '-'

evaluasi_df['Kategori McNemar'] = evaluasi_df.apply(tentukan_kategori, axis=1)

# --- Tampilkan tabel ---
print("\n📋 Tabel Evaluasi Lengkap McNemar NB Crop vs TanpaCrop (80:20):")
display(evaluasi_df)

# --- Simpan tabel evaluasi ke Excel ---
output_excel = '/content/drive/MyDrive/Penelitian/Berkas/cropvsnocrop/Evaluasi_McNemar_NB_Crop_vs_TanpaCrop_80-20.xlsx'
evaluasi_df.to_excel(output_excel, index=False)
print(f"✅ Tabel evaluasi disimpan ke: {output_excel}")

# --- Hitung nilai b dan c untuk McNemar ---
b = sum((evaluasi_df['Crop Benar?']) & (~evaluasi_df['TanpaCrop Benar?']))
c = sum((~evaluasi_df['Crop Benar?']) & (evaluasi_df['TanpaCrop Benar?']))

# --- Buat tabel kontingensi ---
table = [[0, b],
         [c, 0]]

print("\n=== Tabel Kontingensi McNemar ===")
print(pd.DataFrame(table, index=['Crop Benar', 'Crop Salah'], columns=['TanpaCrop Salah', 'TanpaCrop Benar']))

# --- Uji McNemar ---
result = mcnemar(table, exact=True)
print(f"\nHasil Uji McNemar:")
print(f"Statistik: {result.statistic}")
print(f"p-value: {result.pvalue:.4f}")

# Interpretasi
alpha = 0.05
if result.pvalue < alpha:
    print("\nKesimpulan: Terdapat perbedaan signifikan antara model NB Crop dan NB TanpaCrop (p < 0.05)")
else:
    print("\nKesimpulan: Tidak terdapat perbedaan signifikan antara model NB Crop dan NB TanpaCrop (p >= 0.05)")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# 📋 Tabel Evaluasi Lengkap McNemar NB Crop vs TanpaCrop (80:20):
#         Label Asli NB Crop Prediksi NB TanpaCrop Prediksi  Crop Benar?  \
# 0           Matang           Matang        SetengahMatang         True
# 1           Matang           Matang                Matang         True
# 2           Matang           Matang        SetengahMatang         True
# 3           Matang   SetengahMatang        SetengahMatang        False
# 4           Matang           Matang                Matang         True
# 5           Matang   SetengahMatang                Matang        False
# 6           Matang           Matang        SetengahMatang         True
# 7           Matang   SetengahMatang                Matang        False
# 8           Matang           Matang                Matang         True
# 9           Matang           Matang        SetengahMatang         True
# 10          Matang           Matang        SetengahMatang         True
# 11          Matang           Matang        SetengahMatang         True
# 12          Matang           Matang        SetengahMatang         True
# 13          Matang           Matang                Matang         True
# 14          Matang           Matang                Matang         True
# 15          Matang           Matang                Matang         True
# 16          Mentah           Mentah                Mentah         True
# 17          Mentah           Mentah                Mentah         True
# 18          Mentah           Mentah                Mentah         True
# 19          Mentah           Mentah                Mentah         True
# 20          Mentah           Mentah                Mentah         True
# 21          Mentah           Mentah                Mentah         True
# 22          Mentah           Mentah                Mentah         True
# 23          Mentah           Mentah                Mentah         True
# 24          Mentah           Mentah                Mentah         True
# 25  SetengahMatang           Mentah                Mentah        False
# 26  SetengahMatang   SetengahMatang        SetengahMatang         True
# 27  SetengahMatang   SetengahMatang        SetengahMatang         True
# 28  SetengahMatang   SetengahMatang        SetengahMatang         True
# 29  SetengahMatang   SetengahMatang        SetengahMatang         True
# 30  SetengahMatang   SetengahMatang        SetengahMatang         True
# 31  SetengahMatang   SetengahMatang        SetengahMatang         True
# 32  SetengahMatang   SetengahMatang        SetengahMatang         True
# 33  SetengahMatang   SetengahMatang        SetengahMatang         True
# 34  SetengahMatang   SetengahMatang        SetengahMatang         True
# 35  SetengahMatang   SetengahMatang        SetengahMatang         True
# 36  SetengahMatang   SetengahMatang                Matang         True
# 37          Matang           Matang                Matang         True
# 38          Mentah           Mentah                Mentah         True
# 39          Mentah           Mentah                Matang         True
# 40  SetengahMatang   SetengahMatang        SetengahMatang         True
# 41  SetengahMatang   SetengahMatang        SetengahMatang         True
#
#     TanpaCrop Benar?                 Kategori McNemar
# 0              False  b (Crop benar, TanpaCrop salah)
# 1               True                                -
# 2              False  b (Crop benar, TanpaCrop salah)
# 3              False                                -
# 4               True                                -
# 5               True  c (Crop salah, TanpaCrop benar)
# 6              False  b (Crop benar, TanpaCrop salah)
# 7               True  c (Crop salah, TanpaCrop benar)
# 8               True                                -
# 9              False  b (Crop benar, TanpaCrop salah)
# 10             False  b (Crop benar, TanpaCrop salah)
# 11             False  b (Crop benar, TanpaCrop salah)
# 12             False  b (Crop benar, TanpaCrop salah)
# 13              True                                -
# 14              True                                -
# 15              True                                -
# 16              True                                -
# 17              True                                -
# 18              True                                -
# 19              True                                -
# 20              True                                -
# 21              True                                -
# 22              True                                -
# 23              True                                -
# 24              True                                -
# 25             False                                -
# 26              True                                -
# 27              True                                -
# 28              True                                -
# 29              True                                -
# 30              True                                -
# 31              True                                -
# 32              True                                -
# 33              True                                -
# 34              True                                -
# 35              True                                -
# 36             False  b (Crop benar, TanpaCrop salah)
# 37              True                                -
# 38              True                                -
# 39             False  b (Crop benar, TanpaCrop salah)
# 40              True                                -
# 41              True                                -
# ✅ Tabel evaluasi disimpan ke: /content/drive/MyDrive/Penelitian/Berkas/cropvsnocrop/Evaluasi_McNemar_NB_Crop_vs_TanpaCrop_80-20.xlsx
#
# === Tabel Kontingensi McNemar ===
#             TanpaCrop Salah  TanpaCrop Benar
# Crop Benar                0                9
# Crop Salah                2                0
#
# Hasil Uji McNemar:
# Statistik: 2.0
# p-value: 0.0654
#
# Kesimpulan: Tidak terdapat perbedaan signifikan antara model NB Crop dan NB TanpaCrop (p >= 0.05)

# %% [markdown]
# # New Section
